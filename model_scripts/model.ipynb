# %%
# !git clone https://github.com/KupynOrest/DeblurGAN.git
# Out:
# Cloning into 'DeblurGAN'...
# remote: Enumerating objects: 356, done.
# remote: Total 356 (delta 0), reused 0 (delta 0), pack-reused 356
# Receiving objects: 100% (356/356), 85.86 MiB | 23.00 MiB/s, done.
# Resolving deltas: 100% (189/189), done.

# %%
# %pwd
# !python datasets/combine_A_and_B.py --fold_A /content/DeblurGAN/alpha/A --fold_B /content/DeblurGAN/alpha/B --fold_AB /content/DeblurGAN/alpha1
# Out:
# [fold_A] =  /content/DeblurGAN/alpha/A
# [fold_B] =  /content/DeblurGAN/alpha/B
# [fold_AB] =  /content/DeblurGAN/alpha1
# [num_imgs] =  33
# [use_AB] =  False
# split = .ipynb_checkpoints, use 0/0 images
# split = .ipynb_checkpoints, number of images = 0
# split = test, use 3/3 images
# split = test, number of images = 3
# split = train, use 27/27 images
# split = train, number of images = 27
# split = val, use 3/3 images
# split = val, number of images = 3

# %%
pwd
# Out:
# '/content/DeblurGAN'

# %%
# !python train.py --dataroot /.alpha1 --learn_residual --resize_or_crop crop --fineSize 256
# Out:
# Streaming output truncated to the last 5000 lines.
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/usr/local/lib/python3.7/dist-packages/urllib3/util/retry.py", line 399, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='localhost', port=8097): Max retries exceeded with url: /events (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f92b788a550>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
# !python test.py --dataroot /content/DeblurGAN/alpha1 --model test --dataset_mode single --learn_residual
# Out:
# ------------ Options -------------
# aspect_ratio: 1.0
# batchSize: 1
# checkpoints_dir: ./checkpoints
# dataroot: /content/DeblurGAN/alpha1
# dataset_mode: single
# display_id: 1
# display_port: 8097
# display_single_pane_ncols: 0
# display_winsize: 256
# fineSize: 256
# gan_type: wgan-gp
# gpu_ids: [0]
# how_many: 5000
# input_nc: 3
# isTrain: False
# learn_residual: True
# loadSizeX: 640
# loadSizeY: 360
# max_dataset_size: inf
# model: test
# nThreads: 2
# n_layers_D: 3
# name: experiment_name
# ndf: 64
# ngf: 64
# no_dropout: False
# no_flip: False
# norm: instance
# ntest: inf
# output_nc: 3
# phase: test
# resize_or_crop: resize_and_crop
# results_dir: ./results/
# serial_batches: False
# which_direction: AtoB
# which_epoch: latest
# which_model_netD: basic
# which_model_netG: resnet_9blocks
# -------------- End ----------------
# Opt.nThreads =  1
# ...

# %%
# !python train.py --dataroot /content/DeblurGAN/alpha --learn_residual --resize_or_crop crop --fineSize 256
# Out:
# ------------ Options -------------
# batchSize: 1
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: False
# dataroot: /content/DeblurGAN/alpha
# dataset_mode: aligned
# display_freq: 100
# display_id: 1
# display_port: 8097
# display_single_pane_ncols: 0
# display_winsize: 256
# epoch_count: 1
# fineSize: 256
# gan_type: wgan-gp
# gpu_ids: [0]
# identity: 0.0
# input_nc: 3
# isTrain: True
# lambda_A: 100.0
# lambda_B: 10.0
# learn_residual: True
# loadSizeX: 640
# loadSizeY: 360
# lr: 0.0001
# max_dataset_size: inf
# model: content_gan
# nThreads: 2
# n_layers_D: 3
# name: experiment_name
# ndf: 64
# ngf: 64
# niter: 150
# niter_decay: 150
# no_dropout: False
# no_flip: False
# no_html: False
# norm: instance
# output_nc: 3
# phase: train
# pool_size: 50
# print_freq: 100
# resize_or_crop: crop
# save_epoch_freq: 5
# save_latest_freq: 5000
# serial_batches: False
# which_direction: AtoB
# which_epoch: latest
# which_model_netD: basic
# which_model_netG: resnet_9blocks
# ...

# %%
# !pip install dominate
# !pip install ssim
# %cd DeblurGAN 
#!python test.py --dataroot ./abc --model test --dataset_mode single --learn_residual
# Out:
# ...
#   Created wheel for ssim: filename=ssim-0.3.0-py3-none-any.whl size=9712 sha256=2ff9d456848a6ea52d1bde0fcacf648fc6499f8778393688fbab5782c2df17f3
#   Stored in directory: /root/.cache/pip/wheels/26/f2/d9/3a314d056a36ef6b9bccf24c14b2370e2e32689d37b8b65b4a
# Successfully built ssim
# ...
# [Errno 2] No such file or directory: 'DeblurGAN'
# /content/DeblurGAN

# %%
# !pip install visdom
# Out:
# ...
#      |████████████████████████████████| 676 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.8 MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655250 sha256=55b609ae2709c00416840baf54277016fc1e87e130ed49096f92dfb2fd15d061
#   Stored in directory: /root/.cache/pip/wheels/2d/d1/9b/cde923274eac9cbb6ff0d8c7c72fe30a3da9095a38fd50bbf1
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5709 sha256=f7cbaabdd7a8da02e2039a036b6f9816af07346f159d33e9ba8c0ae74d4f8d77
#   Stored in directory: /root/.cache/pip/wheels/ac/5c/3a/a80e1c65880945c71fd833408cd1e9a8cb7e2f8f37620bb75b
# Successfully built visdom torchfile
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True
